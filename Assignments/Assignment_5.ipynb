# %% [markdown]
# <a href="https://colab.research.google.com/github/wcj365/python-stats-dataviz/blob/master/fall2024/Session_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Session 05

# %%
import pandas as pd
import plotly.express as px

pd.set_option("display.max_rows", None)

df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")

df.shape
# Out:
# (4123, 9)

# %%
df.sample(5)
# Out:
#       Year           Country  GDP per capita (current US$)  \
# 1315  2008  French Polynesia                  25437.668582
# 214   2009           Austria                  48153.324020
# 2140  2016           Liberia                    722.131227
# 2262  2005            Malawi                    417.102263
# 2453  2006           Moldova                   1183.024814
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 1315                                80.301000           280558.0          PYF
# 214                                 80.331707          8343323.0          AUT
# 2140                                60.416000          4706097.0          LBR
# 2262                                52.044000         12755648.0          MWI
# 2453                                68.479000          2880967.0          MDA
#
#                      Region         Income Group    Lending Type
# 1315    East Asia & Pacific          High income  Not classified
# 214   Europe & Central Asia          High income  Not classified
# 2140    Sub-Saharan Africa            Low income             IDA
# 2262    Sub-Saharan Africa            Low income             IDA
# 2453  Europe & Central Asia  Upper middle income            IBRD

# %%
df.isna().sum()
# Out:
# Year                                         0
# Country                                      0
# GDP per capita (current US$)               161
# Life expectancy at birth, total (years)    346
# Population, total                            0
# Country Code                                 0
# Region                                       0
# Income Group                                 0
# Lending Type                                 0
# dtype: int64

# %%
df[["Year", "Country","GDP per capita (current US$)", "Life expectancy at birth, total (years)"]].sample(5)
# Out:
#       Year         Country  GDP per capita (current US$)  \
# 2274  2017          Malawi                    500.165547
# 3912  2021  United Kingdom                  46869.759058
# 3418  2021           Spain                  30488.820953
# 1088  2009         Ecuador                   4240.702593
# 160   2012         Armenia                   3643.715401
#
#       Life expectancy at birth, total (years)
# 2274                                62.977000
# 3912                                80.700000
# 3418                                83.178049
# 1088                                75.184000
# 160                                 73.454000

# %%
df_2022 = df[df["Year"] != 2022]
df_2022.shape
# Out:
# (3906, 9)

# %%
df_2022.isna().sum()
# Out:
# Year                                         0
# Country                                      0
# GDP per capita (current US$)               140
# Life expectancy at birth, total (years)    129
# Population, total                            0
# Country Code                                 0
# Region                                       0
# Income Group                                 0
# Lending Type                                 0
# dtype: int64

# %%
df_2022 = df_2022.dropna()
df_2022.isna().sum()
# Out:
# Year                                       0
# Country                                    0
# GDP per capita (current US$)               0
# Life expectancy at birth, total (years)    0
# Population, total                          0
# Country Code                               0
# Region                                     0
# Income Group                               0
# Lending Type                               0
# dtype: int64

# %%
df_2022.shape
# Out:
# (3641, 9)

# %% [markdown]
# ## Homework Question 1:
#
# to check if this dataset has duplicate rows. If it has, only keep one from the duplicated rows and drop the rest.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Year, Country, GDP per capita (current US$), Life expectancy at birth, total (years), Population, total, Country Code, Region, Income Group, Lending Type]
# Index: []

# %%
df_cleaned = df.drop_duplicates()

print(f"Cleaned shape: {df_cleaned.shape}")
print(df_cleaned.sample(5))
# Out:
# Cleaned shape: (4123, 9)
#       Year                Country  GDP per capita (current US$)  \
# 2076  2009                 Latvia                  12331.928552
# 4037  2013  Virgin Islands (U.S.)                  34597.976694
# 2760  2009        North Macedonia                   4584.712431
# 3228  2021             Seychelles                  12963.058980
# 1647  2017   Hong Kong SAR, China                  46160.429791
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 2076                                73.080488          2141669.0          LVA
# 4037                                78.717073           108041.0          VIR
# 2760                                74.446341          2050671.0          MKD
# 3228                                73.397561            99258.0          SYC
# 1647                                84.680488          7393200.0          HKG
#
#                           Region         Income Group    Lending Type
# 2076       Europe & Central Asia          High income  Not classified
# 4037  Latin America & Caribbean           High income  Not classified
# 2760       Europe & Central Asia  Upper middle income            IBRD
# 3228         Sub-Saharan Africa           High income            IBRD
# 1647         East Asia & Pacific          High income  Not classified

# %% [markdown]
# ## HW Question 2
#
# Find out if there is a relationship between wealth and health
#
# Pick any year worth of data and use plotly express to generate a scatter plot with GDP as x and life expectancy as y.

# %%
year_of_interest = 2019

df_2019 = df[df["Year"] == year_of_interest]
print(df_2019.shape)
df_2019.sample(5)
# Out:
# (217, 9)
#       Year    Country  GDP per capita (current US$)  \
# 1896  2019     Jordan                   4159.653754
# 3530  2019      Sudan                    748.010925
# 2314  2019   Maldives                  11349.859264
# 1592  2019     Guyana                   6477.296726
# 1478  2019  Greenland                  53309.203591
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 1896                                76.044000         10698683.0          JOR
# 3530                                65.876000         43232093.0          SDN
# 2314                                80.116000           504508.0          MDV
# 1592                                69.124000           798753.0          GUY
# 1478                                72.043659            56225.0          GRL
#
#                           Region         Income Group    Lending Type
# 1896  Middle East & North Africa  Lower middle income            IBRD
# 3530         Sub-Saharan Africa            Low income             IDA
# 2314                  South Asia  Upper middle income             IDA
# 1592  Latin America & Caribbean           High income             IDA
# 1478       Europe & Central Asia          High income  Not classified

# %%
df_2019.isna().sum()
# Out:
# Year                                       0
# Country                                    0
# GDP per capita (current US$)               6
# Life expectancy at birth, total (years)    8
# Population, total                          0
# Country Code                               0
# Region                                     0
# Income Group                               0
# Lending Type                               0
# dtype: int64

# %%
df_2019 = df_2019.dropna(subset=["GDP per capita (current US$)", "Life expectancy at birth, total (years)"])
print(df_2019.shape)
df_2019.sample(5)
# Out:
# (203, 9)
#       Year       Country  GDP per capita (current US$)  \
# 3017  2019   Puerto Rico                  32916.866801
# 1060  2019      Dominica                   8561.587011
# 281   2019       Bahrain                  25869.112913
# 3378  2019  South Africa                   6702.526617
# 1041  2019      Djibouti                   2876.043664
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 3017                                   79.063          3193694.0          PRI
# 1060                                   73.559            71428.0          DMA
# 281                                    80.019          1494188.0          BHR
# 3378                                   66.175         58087055.0          ZAF
# 1041                                   63.085          1073994.0          DJI
#
#                           Region         Income Group    Lending Type
# 3017  Latin America & Caribbean           High income  Not classified
# 1060  Latin America & Caribbean   Upper middle income           Blend
# 281   Middle East & North Africa          High income  Not classified
# 3378         Sub-Saharan Africa   Upper middle income            IBRD
# 1041  Middle East & North Africa  Lower middle income             IDA

# %%
fig = px.scatter(
    df_2019,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    color="Country",
    size="Population, total",
    title=f"Relationship between GDP per Capita and Life Expectancy in {year_of_interest}",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    }
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="35bc4ef9-f348-47b7-ad88-c991f28a4095" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35bc4ef9-f348-47b7-ad88-c991f28a4095")) {                    Plotly.newPlot(                        "35bc4ef9-f348-47b7-ad88-c991f28a4095",                        [{"hovertemplate":"Country=Afghanistan\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afghanistan","marker":{"color":"#636efa","size":[37769499.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Afghanistan","orientation":"v","showlegend":true,"x":[497.741429257502],"xaxis":"x","y":[63.565],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Albania\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Albania","marker":{"color":"#EF553B","size":[2854191.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Albania","orientation":"v","showlegend":true,"x":[5396.2142432843],"xaxis":"x","y":[79.282],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Algeria\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Algeria","marker":{"color":"#00cc96","size":[42705368.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Algeria","orientation":"v","showlegend":true,"x":[4021.9832660524],"xaxis":"x","y":[76.474],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Angola\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Angola","marker":{"color":"#ab63fa","size":[32353588.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Angola","orientation":"v","showlegend":true,"x":[2191.34776373555],"xaxis":"x","y":[62.448],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Antigua and Barbuda\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Antigua and Barbuda","marker":{"color":"#FFA15A","size":[92117.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Antigua and Barbuda","orientation":"v","showlegend":true,"x":[18730.0047966374],"xaxis":"x","y":[78.691],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Argentina\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Argentina","marker":{"color":"#19d3f3","size":[44938712.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Argentina","orientation":"v","showlegend":true,"x":[9963.67416171662],"xaxis":"x","y":[77.284],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Armenia\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Armenia","marker":{"color":"#FF6692","size":[2820602.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Armenia","orientation":"v","showlegend":true,"x":[4828.50488626598],"xaxis":"x","y":[75.439],"yaxis":"y"," ...

# %% [markdown]
# ## Compare China, US, India, Russia

# %%
df_4_countries = df_2019[df_2019["Country Code"].isin(["USA", "CHN", "IND", "RUS"])]
print(df_4_countries.shape)
df_4_countries
# Out:
# (4, 9)
#       Year             Country  GDP per capita (current US$)  \
# 794   2019               China                  10143.860221
# 1706  2019               India                   2050.163800
# 3074  2019  Russian Federation                  11536.258789
# 3929  2019       United States                  65120.394663
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 794                                 77.968000       1.407745e+09          CHN
# 1706                                70.910000       1.383112e+09          IND
# 3074                                73.083902       1.444063e+08          RUS
# 3929                                78.787805       3.283300e+08          USA
#
#                      Region         Income Group    Lending Type
# 794     East Asia & Pacific  Upper middle income            IBRD
# 1706             South Asia  Lower middle income            IBRD
# 3074  Europe & Central Asia  Upper middle income            IBRD
# 3929          North America          High income  Not classified

# %%
fig = px.scatter(
    df_4_countries,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    color="Country",
    text="Country",
    size="Population, total",
    title=f"Relationship between GDP per Capita and Life Expectancy in {year_of_interest}",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    },
    height=600,
    width=1000
)

# Update text position
fig.update_traces(textposition='top center')
fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d1201d90-ad55-4356-a195-a43b8288358d" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1201d90-ad55-4356-a195-a43b8288358d")) {                    Plotly.newPlot(                        "d1201d90-ad55-4356-a195-a43b8288358d",                        [{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","marker":{"color":"#636efa","size":[1407745000.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"China","orientation":"v","showlegend":true,"text":["China"],"x":[10143.8602205959],"xaxis":"x","y":[77.968],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"India","marker":{"color":"#EF553B","size":[1383112050.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"India","orientation":"v","showlegend":true,"text":["India"],"x":[2050.1638002619],"xaxis":"x","y":[70.91],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Russian Federation","marker":{"color":"#00cc96","size":[144406261.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"Russian Federation","orientation":"v","showlegend":true,"text":["Russian Federation"],"x":[11536.2587890625],"xaxis":"x","y":[73.0839024390244],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","marker":{"color":"#ab63fa","size":[328329953.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"United States","orientation":"v","showlegend":true,"text":["United States"],"x":[65120.3946628653],"xaxis":"x","y":[78.7878048780488],"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888 ...

# %%
df_quad = df[df["Country Code"].isin(["USA", "CHN", "IND", "RUS"])]
print(df_quad.shape)
df_quad.sample(5)
# Out:
# (76, 9)
#       Year             Country  GDP per capita (current US$)  \
# 780   2005               China                   1753.414192
# 794   2019               China                  10143.860221
# 3925  2015       United States                  56762.729452
# 784   2009               China                   3832.227457
# 3073  2018  Russian Federation                  11287.354492
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 780                                 74.111000       1.303720e+09          CHN
# 794                                 77.968000       1.407745e+09          CHN
# 3925                                78.690244       3.207390e+08          USA
# 784                                 75.343000       1.331260e+09          CHN
# 3073                                72.662195       1.444779e+08          RUS
#
#                      Region         Income Group    Lending Type
# 780     East Asia & Pacific  Upper middle income            IBRD
# 794     East Asia & Pacific  Upper middle income            IBRD
# 3925          North America          High income  Not classified
# 784     East Asia & Pacific  Upper middle income            IBRD
# 3073  Europe & Central Asia  Upper middle income            IBRD

# %%
fig = px.line(
    df_quad,
    x="Year",
    color="Country",
    y="GDP per capita (current US$)"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b6a11055-a84a-4830-a422-f06c77a139a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6a11055-a84a-4830-a422-f06c77a139a3")) {                    Plotly.newPlot(                        "b6a11055-a84a-4830-a422-f06c77a139a3",                        [{"hovertemplate":"Country=China\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"China","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[1508.66791563578,1753.41419162417,2099.2194300786,2693.95873162278,3468.32706308591,3832.22745696438,4550.47394361131,5614.3860223103,6300.58217952904,7020.38607424065,7636.0743401587,8016.44559491162,8094.39016730811,8817.04560829162,9905.40638307759,10143.8602205959,10408.7195541075,12617.5051041181,12720.2163182363],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=India\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"India","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"India","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[624.105094381691,710.509344848758,802.013742049265,1022.73246704551,993.503405266506,1096.63613605519,1350.63447029491,1449.60330101563,1434.01798721629,1438.05700508042,1559.86377870535,1590.17433135955,1714.27953740039,1957.96981329558,1974.3777314935,2050.1638002619,1913.21973278751,2238.12714218765,2410.88802070689],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Russian Federation\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Russian Federation","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Russian Federation","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[4102.36474609375,5323.455078125,6920.19970703125,9101.2392578125,11635.2841796875,8562.82421875,10674.990234375,14311.064453125,15420.859375,15974.6220703125,14095.646484375,9313.021484375,8704.89453125,10720.33203125,11287.3544921875,11536.2587890625,10194.44140625,12532.05078125,15270.7060546875],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=United States\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"United States","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[41724.6316287624,44123.4070679055,46302.0008800056,48050.2237771135,48570.0459804586,47194.9433547336,48650.6431283336,50065.9665041742,51784.4185738837,53291.1276891406,55123.8497869046,56762.7294515989,57866.7449341091,59907.754260885,62823.309438197,65120.3946628653,63528.6343027508,70219.472454115,76329.5822652029],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555555555555 ...

# %%
df_group = df.groupby(["Year", "Region"])["Population, total"].sum().reset_index()
df_group
# Out:
#      Year                      Region  Population, total
# 0    2004         East Asia & Pacific       2.094011e+09
# 1    2004       Europe & Central Asia       8.702708e+08
# 2    2004  Latin America & Caribbean        5.498976e+08
# 3    2004  Middle East & North Africa       3.470449e+08
# 4    2004               North America       3.248097e+08
# 5    2004                  South Asia       1.515703e+09
# 6    2004         Sub-Saharan Africa        7.465468e+08
# 7    2005         East Asia & Pacific       2.109795e+09
# 8    2005       Europe & Central Asia       8.729137e+08
# 9    2005  Latin America & Caribbean        5.567395e+08
# 10   2005  Middle East & North Africa       3.544624e+08
# 11   2005               North America       3.278245e+08
# 12   2005                  South Asia       1.541264e+09
# 13   2005         Sub-Saharan Africa        7.669787e+08
# 14   2006         East Asia & Pacific       2.125591e+09
# 15   2006       Europe & Central Asia       8.756279e+08
# 16   2006  Latin America & Caribbean        5.634241e+08
# 17   2006  Middle East & North Africa       3.626340e+08
# 18   2006               North America       3.310156e+08
# 19   2006                  South Asia       1.565893e+09
# 20   2006         Sub-Saharan Africa        7.881100e+08
# 21   2007         East Asia & Pacific       2.141253e+09
# 22   2007       Europe & Central Asia       8.784563e+08
# 23   2007  Latin America & Caribbean        5.699722e+08
# 24   2007  Middle East & North Africa       3.713248e+08
# 25   2007               North America       3.341851e+08
# 26   2007                  South Asia       1.589455e+09
# 27   2007         Sub-Saharan Africa        8.100193e+08
# 28   2008         East Asia & Pacific       2.156920e+09
# 29   2008       Europe & Central Asia       8.820884e+08
# 30   2008  Latin America & Caribbean        5.763862e+08
# 31   2008  Middle East & North Africa       3.802941e+08
# 32   2008               North America       3.374064e+08
# 33   2008                  South Asia       1.612709e+09
# 34   2008         Sub-Saharan Africa        8.326427e+08
# 35   2009         East Asia & Pacific       2.172100e+09
# 36   2009       Europe & Central Asia       8.856598e+08
# 37   2009  Latin America & Caribbean        5.827381e+08
# 38   2009  Middle East & North Africa       3.893324e+08
# 39   2009               North America       3.404661e+08
# 40   2009                  South Asia       1.636412e+09
# 41   2009         Sub-Saharan Africa        8.558857e+08
# 42   2010         East Asia & Pacific       2.187065e+09
# 43   2010       Europe & Central Asia       8.891696e+08
# 44   2010  Latin America & Caribbean        5.888739e+08
# 45   2010  Middle East & North Africa       3.979976e+08
# 46   2010               North America       3.433972e+08
# 47   2010                  South Asia       1.660546e+09
# 48   2010         Sub-Saharan Africa        8.797974e+08
# 49   2011         East Asia & Pacific       2.202812e+09
# 50   2011       Europe & Central Asia       8.913294e+08
# 51   2011  Latin America & Caribbean        5.955100e+08
# 52   2011  Middle East & North Africa       4.060453e+08
# 53   2011               North America       3.459874e+08
# 54   2011                  South Asia       1.684898e+09
# 55   2011         Sub-Saharan Africa        9.042822e+08
# 56   2012         East Asia & Pacific       2.220515e+09
# 57   2012       Europe & Central Asia       8.946605e+08
# 58   2012  Latin America & Caribbean        6.021394e+08
# 59   2012  Middle East & North Africa       4.141176e+08
# 60   2012               North America       3.486567e+08
# 61   2012                  South Asia       1.708707e+09
# 62   2012         Sub-Saharan Africa        9.293287e+08
# 63   2013         East Asia & Pacific       2.237930e+09
# 64   2013       Europe & Central Asia       8.986074e+08
# 65   2013  Latin America & Caribbean        6.086422e+08
# 66   2013  Middle East & North Africa       4.227904e+08
# 67   2013               North America       3.512079e+08
# 68   2013                  South Asia       1.731684e+09
# 69   2013         Sub-Saharan Africa        9.550967e+08
# 70   2014         East Asia & Pacific       2.254840e+09
# 71   2014       Europe & Central Asia       9.026709e+08
# 72   2014  Latin America & Caribbean        6.150468e+08
# 73   2014  Middle East & North Africa       4.316646e+08
# 74   2014               North America       3.538889e+08
# 75   2014                  South Asia       1.754030e+09
# 76   2014         Sub-Saharan Africa        9.815066e+08
# 77   2015         East Asia & Pacific       2.271045e+09
# 78   2015       Europe & Central Asia       9.066954e+08
# 79   2015  Latin America & Caribbean        6.213901e+08
# 80   2015  Middle East & North Africa       4.405065e+08
# 81   2015               North America       3.565071e+08
# 82   2015                  South Asia       1.775545e+09
# 83   2015         Sub-Saharan Africa        1.008699e+09
# 84   2016         East Asia & Pacific       2.287214e+09
# 85   2016       Europe & Central Asia       9.106333e+08
# 86   2016  Latin America & Caribbean        6.276685e+08
# 87   2016  Middle East & North Africa       4.489174e+08
# 88   2016               North America       3.592458e+08
# 89   2016                  South Asia       1.797073e+09
# 90   2016         Sub-Saharan Africa        1.036156e+09
# 91   2017         East Asia & Pacific       2.303580e+09
# 92   2017       Europe & Central Asia       9.140783e+08
# 93   2017  Latin America & Caribbean        6.337972e+08
# 94   2017  Middle East & North Africa       4.568855e+08
# 95   2017               North America       3.617312e+08
# 96   2017                  South Asia       1.818932e+09
# 97   2017         Sub-Saharan Africa        1.063885e+09
# 98   2018         East Asia & Pacific       2.317809e+09
# 99   2018       Europe & Central Asia       9.173805e+08
# 100  2018  Latin America & Caribbean        6.396282e+08
# 101  2018  Middle East & North Africa       4.650735e+08
# 102  2018               North America       3.639672e+08
# 103  2018                  South Asia       1.840534e+09
# 104  2018         Sub-Saharan Africa        1.092404e+09
# 105  2019         East Asia & Pacific       2.330266e+09
# 106  2019       Europe & Central Asia       9.202775e+08
# 107  2019  Latin America & Caribbean        6.452958e+08
# 108  2019  Middle East & North Africa       4.732018e+08
# 109  2019               North America       3.659951e+08
# 110  2019                  South Asia       1.861599e+09
# 111  2019         Sub-Saharan Africa        1.121549e+09
# 112  2020         East Asia & Pacific       2.340351e+09
# 113  2020       Europe & Central Asia       9.223534e+08
# 114  2020  Latin America & Caribbean        6.505350e+08
# 115  2020  Middle East & North Africa       4.799666e+08
# 116  2020               North America       3.695826e+08
# 117  2020                  South Asia       1.882532e+09
# 118  2020         Sub-Saharan Africa        1.151302e+09
# 119  2021         East Asia & Pacific       2.346702e+09
# 120  2021       Europe & Central Asia       9.235640e+08
# 121  2021  Latin America & Caribbean        6.549806e+08
# 122  2021  Middle East & North Africa       4.861748e+08
# 123  2021               North America       3.703218e+08
# 124  2021                  South Asia       1.901912e+09
# 125  2021         Sub-Saharan Africa        1.181163e+09
# 126  2022         East Asia & Pacific       2.351976e+09
# 127  2022       Europe & Central Asia       9.203756e+08
# 128  2022  Latin America & Caribbean        6.593106e+08
# 129  2022  Middle East & North Africa       4.932795e+08
# 130  2022               North America       3.722810e+08
# 131  2022                  South Asia       1.919348e+09
# 132  2022         Sub-Saharan Africa        1.211190e+09

# %% [markdown]
# Home work #5
# Pick a few countries of your interest (for example, G7, BRICS, Nordic countries).
# - 1 Create a line chart showing the trend of Life Expectancy over time for comparing those countries.
# - 2 Pick a year from the data of the above few countries and create a scatter plot to compare their GDP per capita and life expectancy. The size of the dots represent the population. This type of scatter plot is called bubble chart.
# - 3 Bonus - compute the average GDP per capita, the average life expectancy, and the total population for each year of all the seven regions (aggregation) and repeat 1 and 2 using the aggregated data for all regions

# %%
df_quad['Country Code'].unique()
# Out:
# array(['CHN', 'IND', 'RUS', 'USA'], dtype=object)

# %%
df_quad['Year'].unique()
# Out:
# array([2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022])

# %%
#1 Create a line chart showing the trend of Life Expectancy over time for comparing those countries.

fig = px.line(
    df_quad,
    x="Year",
    color="Country",
    y="Life expectancy at birth, total (years)",
    title = 'Life Expectenct vs Year on Country'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a24055a4-e862-422c-9a13-9089d13f5cb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a24055a4-e862-422c-9a13-9089d13f5cb0")) {                    Plotly.newPlot(                        "a24055a4-e862-422c-9a13-9089d13f5cb0",                        [{"hovertemplate":"Country=China\u003cbr\u003eYear=%{x}\u003cbr\u003eLife expectancy at birth, total (years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"China","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[73.748,74.111,74.504,74.762,74.872,75.343,75.599,75.903,76.192,76.452,76.717,76.977,77.218,77.248,77.744,77.968,78.077,78.211,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=India\u003cbr\u003eYear=%{x}\u003cbr\u003eLife expectancy at birth, total (years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"India","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"India","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[64.524,64.996,65.412,65.788,66.149,66.513,66.909,67.359,67.887,68.46,69.074,69.636,70.117,70.467,70.71,70.91,70.15,67.24,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Russian Federation\u003cbr\u003eYear=%{x}\u003cbr\u003eLife expectancy at birth, total (years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Russian Federation","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Russian Federation","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[65.4709756097561,65.529756097561,66.7275609756098,67.5868292682927,67.9492682926829,68.6846341463415,68.8412195121951,69.6839024390244,70.0721951219512,70.5787804878049,70.7436585365854,71.1834146341463,71.6512195121951,72.4514634146342,72.6621951219512,73.0839024390244,71.3387804878049,69.3612195121951,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=United States\u003cbr\u003eYear=%{x}\u003cbr\u003eLife expectancy at birth, total (years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"United States","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[77.4878048780488,77.4878048780488,77.6878048780488,77.9878048780488,78.0390243902439,78.390243902439,78.5414634146342,78.6414634146341,78.7414634146342,78.7414634146342,78.8414634146341,78.690243902439,78.5390243902439,78.5390243902439,78.6390243902439,78.7878048780488,76.9804878048781,76.3292682926829,null],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f ...

# %%
#2 Pick a year from the data of the above few countries and create a scatter plot to compare their GDP per capita and life expectancy. The size of the dots represent the population. This type of scatter plot is called bubble chart.
year_of_interest = 2006
df_squad_2006 = df_quad[df_quad["Year"] == year_of_interest]
print(df_squad_2006.shape)
df_squad_2006
# Out:
# (4, 9)
#       Year             Country  GDP per capita (current US$)  \
# 781   2006               China                   2099.219430
# 1693  2006               India                    802.013742
# 3061  2006  Russian Federation                   6920.199707
# 3916  2006       United States                  46302.000880
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 781                                 74.504000       1.311020e+09          CHN
# 1693                                65.412000       1.172374e+09          IND
# 3061                                66.727561       1.430496e+08          RUS
# 3916                                77.687805       2.983799e+08          USA
#
#                      Region         Income Group    Lending Type
# 781     East Asia & Pacific  Upper middle income            IBRD
# 1693             South Asia  Lower middle income            IBRD
# 3061  Europe & Central Asia  Upper middle income            IBRD
# 3916          North America          High income  Not classified

# %%
fig = px.scatter(
    df_squad_2006,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    color="Country",
    text="Country",
    size="Population, total",
    title=f"Relationship between GDP per Capita and Life Expectancy in {year_of_interest}",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    },
    height=600,
    width=1000
)

# Update text position
fig.update_traces(textposition='top center')
fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ab65ccee-9637-4ae1-8b48-a89499ddc468" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab65ccee-9637-4ae1-8b48-a89499ddc468")) {                    Plotly.newPlot(                        "ab65ccee-9637-4ae1-8b48-a89499ddc468",                        [{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","marker":{"color":"#636efa","size":[1311020000.0],"sizemode":"area","sizeref":3277550.0,"symbol":"circle"},"mode":"markers+text","name":"China","orientation":"v","showlegend":true,"text":["China"],"x":[2099.2194300786],"xaxis":"x","y":[74.504],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"India","marker":{"color":"#EF553B","size":[1172373788.0],"sizemode":"area","sizeref":3277550.0,"symbol":"circle"},"mode":"markers+text","name":"India","orientation":"v","showlegend":true,"text":["India"],"x":[802.013742049265],"xaxis":"x","y":[65.412],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Russian Federation","marker":{"color":"#00cc96","size":[143049637.0],"sizemode":"area","sizeref":3277550.0,"symbol":"circle"},"mode":"markers+text","name":"Russian Federation","orientation":"v","showlegend":true,"text":["Russian Federation"],"x":[6920.19970703125],"xaxis":"x","y":[66.7275609756098],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","marker":{"color":"#ab63fa","size":[298379912.0],"sizemode":"area","sizeref":3277550.0,"symbol":"circle"},"mode":"markers+text","name":"United States","orientation":"v","showlegend":true,"text":["United States"],"x":[46302.0008800056],"xaxis":"x","y":[77.6878048780488],"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888 ...

# %%
#3 Bonus - compute the average GDP per capita, the average life expectancy, and the total population for each year of all the seven regions (aggregation) and repeat 1 and 2 using the aggregated data for all regions

# %%
df.isna().sum()
# Out:
# Year                                         0
# Country                                      0
# GDP per capita (current US$)               161
# Life expectancy at birth, total (years)    346
# Population, total                            0
# Country Code                                 0
# Region                                       0
# Income Group                                 0
# Lending Type                                 0
# dtype: int64

# %%
df_refined = df.dropna()
df_refined.isna().sum()
# Out:
# Year                                       0
# Country                                    0
# GDP per capita (current US$)               0
# Life expectancy at birth, total (years)    0
# Population, total                          0
# Country Code                               0
# Region                                     0
# Income Group                               0
# Lending Type                               0
# dtype: int64

# %%
df_refined.head()
# Out:
#    Year      Country  GDP per capita (current US$)  \
# 0  2004  Afghanistan                    221.830531
# 1  2005  Afghanistan                    254.115274
# 2  2006  Afghanistan                    274.015394
# 3  2007  Afghanistan                    376.318296
# 4  2008  Afghanistan                    382.533804
#
#    Life expectancy at birth, total (years)  Population, total Country Code  \
# 0                                   57.944         23553551.0          AFG
# 1                                   58.361         24411191.0          AFG
# 2                                   58.684         25442944.0          AFG
# 3                                   59.111         25903301.0          AFG
# 4                                   59.852         26427199.0          AFG
#
#        Region Income Group Lending Type
# 0  South Asia   Low income          IDA
# 1  South Asia   Low income          IDA
# 2  South Asia   Low income          IDA
# 3  South Asia   Low income          IDA
# 4  South Asia   Low income          IDA

# %%
df_group = df_refined.groupby(["Region", "Year"]).agg({'GDP per capita (current US$)': 'mean', 'Life expectancy at birth, total (years)': 'mean','Population, total': 'sum'})
df_group.head()
# Out:
#                           GDP per capita (current US$)  \
# Region              Year
# East Asia & Pacific 2004                   9718.727162
#                     2005                  10498.356382
#                     2006                  11265.024739
#                     2007                  12654.643753
#                     2008                  13567.862701
#
#                           Life expectancy at birth, total (years)  \
# Region              Year
# East Asia & Pacific 2004                                71.266636
#                     2005                                71.478419
#                     2006                                71.828068
#                     2007                                72.021120
#                     2008                                72.031479
#
#                           Population, total
# Region              Year
# East Asia & Pacific 2004       2.069903e+09
#                     2005       2.085558e+09
#                     2006       2.101203e+09
#                     2007       2.116748e+09
#                     2008       2.132306e+09

# %%
df_group_reset = df_group.reset_index()
df_group_reset.head()
# Out:
#                 Region  Year  GDP per capita (current US$)  \
# 0  East Asia & Pacific  2004                   9718.727162
# 1  East Asia & Pacific  2005                  10498.356382
# 2  East Asia & Pacific  2006                  11265.024739
# 3  East Asia & Pacific  2007                  12654.643753
# 4  East Asia & Pacific  2008                  13567.862701
#
#    Life expectancy at birth, total (years)  Population, total
# 0                                71.266636       2.069903e+09
# 1                                71.478419       2.085558e+09
# 2                                71.828068       2.101203e+09
# 3                                72.021120       2.116748e+09
# 4                                72.031479       2.132306e+09

# %%
fig = px.line(
    df_group_reset,
    x="Year",
    color="Region",
    y="Life expectancy at birth, total (years)",
    title = 'Life Expectenct vs Year on Region'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="02252c90-2234-4e28-bc7f-615481815aaf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02252c90-2234-4e28-bc7f-615481815aaf")) {                    Plotly.newPlot(                        "02252c90-2234-4e28-bc7f-615481815aaf",                        [{"hovertemplate":"Region=East Asia & Pacific\u003cbr\u003eYear=%{x}\u003cbr\u003eLife expectancy at birth, total (years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"East Asia & Pacific","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[71.26663643292683,71.47841906873614,71.82806783536586,72.02111966463414,72.03147865853659,72.4003330792683,72.24953806356247,72.45713008130082,72.66405838876571,72.87207390983002,73.07102365114561,73.23009608277901,73.40283887657058,73.6099623059867,73.87314264597192,74.06883592017739,74.17000886917961,73.65431042128603],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Europe & Central Asia\u003cbr\u003eYear=%{x}\u003cbr\u003eLife expectancy at birth, total (years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Europe & Central Asia","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[74.77327427519559,74.86467924528303,75.16885503911644,75.4234233778187,75.71888541187299,76.0224523699954,76.27795213989877,76.64320938794295,76.84177082374597,77.11640635066729,77.3975747814082,77.40605706396687,77.76041102077687,77.92763459801266,78.05729177958447,78.32488256549233,77.27524119241194,76.97872204325817],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Latin America & Caribbean \u003cbr\u003eYear=%{x}\u003cbr\u003eLife expectancy at birth, total (years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean ","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Latin America & Caribbean ","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[72.11238299274885,72.43056624917601,72.69317270929466,72.8223355306526,73.08547066578774,73.35909822017139,73.28337098844672,73.90045609756098,73.97572983114446,74.09307442151345,74.39852256097561,74.40049165596919,74.5472053915276,74.54748331193838,74.68890573500329,74.79137612323491,73.80085168094925,72.9921919127086],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Middle East & North Africa\u003cbr\u003eYear=%{x}\u003cbr\u003eLife expectancy at birth, total (years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Middle East & North Africa","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Middle East & North Africa","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[72.37166666666667,72.64277235772359,72.80688966318235,73.09993147502904,73.40060975609757,73.75654006968641,74.1584761904762,74.24478281068525,74.24767711962834,74.37635423925667,74.45095238095239,74.7327038327526,74.97042740998839,75.34821718931474,75.54567711962834,75.72125783972126,74.67093147502904,74.36790360046457],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=North America\u003cbr\u003eYear=%{x}\u003cbr\u003eLife expectancy at birth, total (ye ...

# %%
df_grouped_2006 = df_group_reset[df_group_reset["Year"] == 2006]
fig = px.scatter(
    df_grouped_2006,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    color="Region",
    text="Region",
    size="Population, total",
    title=f"Relationship between Average GDP per Capita and Average Life Expectancy in {year_of_interest} on Region",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    },
    height=600,
    width=1000
)

# Update text position
fig.update_traces(textposition='top center')
fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="98abdc1a-7c6c-4363-b53d-c503632948cc" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98abdc1a-7c6c-4363-b53d-c503632948cc")) {                    Plotly.newPlot(                        "98abdc1a-7c6c-4363-b53d-c503632948cc",                        [{"hovertemplate":"Region=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","marker":{"color":"#636efa","size":[2101202616.0],"sizemode":"area","sizeref":5253006.54,"symbol":"circle"},"mode":"markers+text","name":"East Asia & Pacific","orientation":"v","showlegend":true,"text":["East Asia & Pacific"],"x":[11265.024739265204],"xaxis":"x","y":[71.82806783536586],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Region=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","size":[873736620.0],"sizemode":"area","sizeref":5253006.54,"symbol":"circle"},"mode":"markers+text","name":"Europe & Central Asia","orientation":"v","showlegend":true,"text":["Europe & Central Asia"],"x":[25042.19121033146],"xaxis":"x","y":[75.16885503911644],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Region=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean ","marker":{"color":"#00cc96","size":[563142756.0],"sizemode":"area","sizeref":5253006.54,"symbol":"circle"},"mode":"markers+text","name":"Latin America & Caribbean ","orientation":"v","showlegend":true,"text":["Latin America & Caribbean "],"x":[8994.963175136194],"xaxis":"x","y":[72.69317270929466],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Region=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Middle East & North Africa","marker":{"color":"#ab63fa","size":[362633997.0],"sizemode":"area","sizeref":5253006.54,"symbol":"circle"},"mode":"markers+text","name":"Middle East & North Africa","orientation":"v","showlegend":true,"text":["Middle East & North Africa"],"x":[13378.450451811357],"xaxis":"x","y":[72.80688966318235],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Region=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","marker":{"color":"#FFA15A","size":[331015609.0],"sizemode":"area","sizeref":5253006.54,"symbol":"circle"},"mode":"markers+text","name":"North America","orientation":"v","showlegend":true,"text":["North America"],"x":[60675.973492452],"xaxis":"x","y":[78.60548780487807],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Region=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South Asia","marker":{"color":"#19d3f3","size":[1565892885.0],"sizemode":"area","sizeref":5253006.54,"symbol":"circle"},"mode":"markers+text","name":"South Asia","orientation":"v","showlegend":true,"text":["South Asia"],"x":[1320.326664490 ...

# %% [markdown]
# ## Homework Question 3
#
# Select a year of data. calculate total population of each region and make a pie chart to display the distribution of total population of all regions.

# %%
df_filtered = df_filtered.dropna(subset=["Population, total", "Region"])

population_by_region = df_filtered.groupby("Region")["Population, total"].sum().reset_index()


fig = px.pie(
    population_by_region,
    values='Population, total',
    names='Region',
    title=f"Total Population Distribution by Region in {year_of_interest}",
    labels={'Population, total': 'Total Population'}
)

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4ed8051b-6ed0-4c82-9393-2f6536fe94ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ed8051b-6ed0-4c82-9393-2f6536fe94ca")) {                    Plotly.newPlot(                        "4ed8051b-6ed0-4c82-9393-2f6536fe94ca",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Region=%{label}\u003cbr\u003eTotal Population=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["East Asia & Pacific","Europe & Central Asia","Latin America & Caribbean ","Middle East & North Africa","North America","South Asia","Sub-Saharan Africa "],"legendgroup":"","name":"","showlegend":true,"values":[2304395299.0,920097241.0,616069936.0,473201775.0,365995094.0,1861598514.0,1107602565.0],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0 ...

# %% [markdown]
# ## Exercise
#
# Calculate average GDP per capita for  each region and make a bar chart.

# %%
df_cleaned = df[['Region', 'GDP per capita (current US$)']].dropna()

average_gdp_by_region = df_cleaned.groupby('Region').agg({'GDP per capita (current US$)': 'mean'}).reset_index()
fig = px.bar(
    data_frame=average_gdp_by_region,
    x='Region',
    y='GDP per capita (current US$)',
    title='Average GDP per Capita by Region',
    labels={
        'GDP per capita (current US$)': 'Average GDP per Capita (Current US$)',
        'Region': 'Region'
    },
    text='GDP per capita (current US$)'
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f3563dcf-968e-4c98-825b-fdf08e3dd91e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3563dcf-968e-4c98-825b-fdf08e3dd91e")) {                    Plotly.newPlot(                        "f3563dcf-968e-4c98-825b-fdf08e3dd91e",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[15178.57870244265,32834.03708256286,13226.709551141275,15653.223443831292,67679.3793732906,2357.1715547168174,2271.14379159153],"textposition":"auto","x":["East Asia & Pacific","Europe & Central Asia","Latin America & Caribbean ","Middle East & North Africa","North America","South Asia","Sub-Saharan Africa "],"xaxis":"x","y":[15178.57870244265,32834.03708256286,13226.709551141275,15653.223443831292,67679.3793732906,2357.1715547168174,2271.14379159153],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{ ...

# %%
df_2020 = df3[df3["Year"] == 2020]
df_2020.shape
# Out:
# (202, 9)

# %%
df_2020.sample(5)
# Out:
#       Year     Country  GDP per capita (current US$)  \
# 2999  2020    Portugal                  22242.406418
# 624   2020  Cabo Verde                   3126.399859
# 2258  2020  Madagascar                    462.404229
# 1042  2020    Djibouti                   2921.738706
# 2980  2020      Poland                  15816.820402
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 2999                                 80.97561         10297081.0          PRT
# 624                                  74.80800           582640.0          CPV
# 2258                                 65.18200         28225177.0          MDG
# 1042                                 62.69400          1090156.0          DJI
# 2980                                 76.50000         37899070.0          POL
#
#                           Region         Income Group    Lending Type
# 2999       Europe & Central Asia          High income  Not classified
# 624          Sub-Saharan Africa   Lower middle income           Blend
# 2258         Sub-Saharan Africa            Low income             IDA
# 1042  Middle East & North Africa  Lower middle income             IDA
# 2980       Europe & Central Asia          High income            IBRD

# %%
df_group = df.groupby("Region")["GDP per capita (current US$)"].mean()
df_group
# Out:
# Region
# East Asia & Pacific           15178.578702
# Europe & Central Asia         32834.037083
# Latin America & Caribbean     13226.709551
# Middle East & North Africa    15653.223444
# North America                 67679.379373
# South Asia                     2357.171555
# Sub-Saharan Africa             2271.143792
# Name: GDP per capita (current US$), dtype: float64

# %%
df_group = df_group.reset_index()
df_group
# Out:
#                        Region  GDP per capita (current US$)
# 0         East Asia & Pacific                  15178.578702
# 1       Europe & Central Asia                  32834.037083
# 2  Latin America & Caribbean                   13226.709551
# 3  Middle East & North Africa                  15653.223444
# 4               North America                  67679.379373
# 5                  South Asia                   2357.171555
# 6         Sub-Saharan Africa                    2271.143792

# %%
fig = px.bar(df_group, x="Region", y="GDP per capita (current US$)", color="Region")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4f4158b8-5615-45d5-a9db-877f84f46f9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f4158b8-5615-45d5-a9db-877f84f46f9c")) {                    Plotly.newPlot(                        "4f4158b8-5615-45d5-a9db-877f84f46f9c",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"East Asia & Pacific","offsetgroup":"East Asia & Pacific","orientation":"v","showlegend":true,"textposition":"auto","x":["East Asia & Pacific"],"xaxis":"x","y":[15178.57870244265],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Europe & Central Asia","offsetgroup":"Europe & Central Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Europe & Central Asia"],"xaxis":"x","y":[32834.03708256286],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean ","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Latin America & Caribbean ","offsetgroup":"Latin America & Caribbean ","orientation":"v","showlegend":true,"textposition":"auto","x":["Latin America & Caribbean "],"xaxis":"x","y":[13226.709551141275],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Middle East & North Africa","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Middle East & North Africa","offsetgroup":"Middle East & North Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Middle East & North Africa"],"xaxis":"x","y":[15653.223443831292],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["North America"],"xaxis":"x","y":[67679.3793732906],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South Asia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South Asia","offsetgroup":"South Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["South Asia"],"xaxis":"x","y":[2357.1715547168174],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sub-Saharan Africa ","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Sub-Saharan Africa ","offsetgroup":"Sub-Saharan Africa ","orientation":"v","showlegend":true,"textposition":"auto","x":["Sub-Saharan Africa "],"xaxis":"x","y":[2271.14379159153],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666 ...

# %% [markdown]
# ## Home work question 4
#
# 1. remove the color legend.
# 2. Order the above bar chart based on the values of the average GDP per capita.

# %%
df_group = df_group.sort_values(by="GDP per capita (current US$)", ascending=False)

fig = px.bar(df_group,
             x="Region",
             y="GDP per capita (current US$)",
             color="Region")

fig.update_layout(showlegend=False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="817719ac-fffa-4a5a-b148-dd251c4bdfea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("817719ac-fffa-4a5a-b148-dd251c4bdfea")) {                    Plotly.newPlot(                        "817719ac-fffa-4a5a-b148-dd251c4bdfea",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["North America"],"xaxis":"x","y":[67679.3793732906],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Europe & Central Asia","offsetgroup":"Europe & Central Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Europe & Central Asia"],"xaxis":"x","y":[32834.03708256286],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Middle East & North Africa","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Middle East & North Africa","offsetgroup":"Middle East & North Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Middle East & North Africa"],"xaxis":"x","y":[15653.223443831292],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"East Asia & Pacific","offsetgroup":"East Asia & Pacific","orientation":"v","showlegend":true,"textposition":"auto","x":["East Asia & Pacific"],"xaxis":"x","y":[15178.57870244265],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean ","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Latin America & Caribbean ","offsetgroup":"Latin America & Caribbean ","orientation":"v","showlegend":true,"textposition":"auto","x":["Latin America & Caribbean "],"xaxis":"x","y":[13226.709551141275],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South Asia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South Asia","offsetgroup":"South Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["South Asia"],"xaxis":"x","y":[2357.1715547168174],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sub-Saharan Africa ","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Sub-Saharan Africa ","offsetgroup":"Sub-Saharan Africa ","orientation":"v","showlegend":true,"textposition":"auto","x":["Sub-Saharan Africa "],"xaxis":"x","y":[2271.14379159153],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666 ...
